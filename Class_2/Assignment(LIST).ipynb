# %% [markdown]
# ####  Task 1: Onboarding a New Intern
# *Scenario*: You’re managing intern records in a startup. Each intern’s data includes name (str), age (int), stipend (float), and department (str).
#
# 1. **Create** a list called `intern` with: `"Zara"`, `20`, `25000.0`, `"Marketing"`.
# 2. **Slice** the list to extract only the first three items (`name`, `age`, `stipend`) into a new list called `basic_info`.
# 3. The intern switches departments—**update** the department (last item) to `"Product"`.
# 4. A bonus is added—**append** `"Onboarding Complete"` to the list.
# 5. Later, you realize you need to update the stipend, but you don’t know its index. Use `.index(25000.0)` to find it, then **update** it to `28000.0`.
# 6. Before archiving, **remove** `"Onboarding Complete"` using `.remove()`.
# 7. Finally, **delete** the department (`"Product"`) using `.pop()` with the correct index (hint: it’s now the last item).
# 8. Print the final `intern` list—it should contain only `[name, age, updated_stipend]`.

# %%
intern = ["Zara", 20, 25000.0, "Marketing"]

# %%
basic_info = intern[:3]

# %%
intern[-1] = "Product"

# %%
intern.append("Onboarding Complete")

# %%
stipend_index = intern.index(25000.0)
intern[stipend_index] = 28000.0

# %%
intern.remove("Onboarding Complete")

# %%
intern.pop(-1)
# Out:
# 'Product'

# %%
print(intern)
# Out:
# ['Zara', 20, 28000.0]

# %% [markdown]
# #### **Task 2: Managing a Customer Support Ticket**
# *Scenario*: A support ticket is represented as a list containing: customer name, issue ID (int), priority (str), status (str), and resolution time (float in hours).
#
# 1. **Create** a list `ticket` with: `"Ali"`, `1045`, `"High"`, `"Open"`, `0.0`.
# 2. **Slice** to get the core issue info: `[customer name, issue ID, priority]` → store in `issue_summary`.
# 3. The ticket is being worked on—**update** the status (`"Open"`) to `"In Progress"`.
# 4. After 2.5 hours, the issue is resolved—**append** the actual resolution time: `2.5`.
# 5. You need to revise the priority, but aren’t sure where it is. Use `.index("High")` to find its position, then **update** it to `"Medium"`.
# 6. Now, **remove** the old resolution time (`0.0`) using `.remove(0.0)`.
# 7. The system no longer needs the issue ID after resolution—use `.pop(1)` to delete it by index.
# 8. Print the final `ticket` list.

# %% [markdown]
# #### **Task 3: Updating a Student’s Course Registration**
# *Scenario*: A student’s enrollment record includes: name, current semester (int), GPA (float), enrolled course (str), and advisor note (str).
#
# 1. **Create** a list `student` with: `"Hassan"`, `4`, `3.2`, `"Data Structures"`, `"Needs tutoring"`.
# 2. **Slice** to extract academic info: `[name, semester, GPA]` → save as `academic_profile`.
# 3. Hassan drops the course—**update** `"Data Structures"` to `"AI Fundamentals"`.
# 4. He improves his GPA—**append** `"GPA updated"` as a temporary flag.
# 5. To update the GPA properly, locate its index using `.index(3.2)`, then change it to `3.6`.
# 6. **Remove** the temporary flag `"GPA updated"` using `.remove()`.
# 7. The advisor note is no longer relevant—**delete** it using `.pop()` (it’s the last item now).
# 8. Print the final `student` list.

# %% [markdown]
# ### **Task 4: Emergency Contact Update System**
# *Scenario*:
# A hospital maintains emergency contact records as Python lists. Each record contains: patient name (str), age (int), blood type (str), primary contact number (str), and a temporary flag like `"Unverified"` or `"Verified"`.
#
# During a system audit:
# - The staff must extract only the patient’s identity and medical info (name, age, blood type) for a secure printout.
# - The contact number has changed, but the team doesn’t know its position in the list—they only know the old number (`"03001234567"`).
# - After updating the number, they add a note `"Contact updated"` to the end.
# - Once confirmed, they remove the temporary verification flag (which could be either `"Unverified"` or `"Verified"`—you don’t know which one is present).
# - Finally, they realize the audit log accidentally included the note `"Contact updated"` and must delete it—but only after removing the flag, so its index has shifted.
#
# **Your task**: Starting from an initial record like `["Fatima", 68, "B+", "03001234567", "Unverified"]`, write code that processes the entire update workflow and ends with a clean list containing only `[name, age, blood type, new_contact]`.

# %% [markdown]
# ---
#
# ### **Task 5: Inventory Adjustment for a Retail Store**
# *Scenario*:
# A small shop tracks each product as a list: product name (str), current stock (int), price (float), shelf location (str), and a status tag like `"Low Stock"` or `"On Sale"`.
#
# During a weekly review:
# - Managers first generate a summary excluding price and status (i.e., only name, stock, and location).
# - They then restock the item—increasing the stock count—but they don’t remember if stock is at index 1 or not, so they must locate it dynamically using its current value (e.g., if stock is `5`, find where `5` is and update it to `20`).
# - The price is reduced, so they update the price field—but again, without hardcoding the index.
# - The old status tag (e.g., `"Low Stock"`) is no longer valid and must be removed by value.
# - After cleanup, they notice the shelf location was mislabeled and decide to remove it temporarily using its index (knowing it’s now the last meaningful data point), then re-add the correct location using `.append()`.
#
# **Your task**: Begin with a product list like `["Wireless Mouse", 5, 2500.0, "Aisle 3", "Low Stock"]`. Simulate the full adjustment process so the final list reflects the updated stock, new price, and corrected shelf location—with no extra tags or outdated values.

# %% [markdown]
# ### **Debugging Task 1: Employee Promotion Pipeline**
# *Scenario*:
# An HR automation script is supposed to update an employee’s record after a promotion. The final list should contain: `[name, new_age, new_salary, department]`.
#
# **Buggy Code**:
# ```python
# employee = ["Kamran", 29, 60000, "Finance"]
# # Step 1: Extract personal info (name and age)
# personal = employee[0:1]  # Intended: get name and age
#
# # Step 2: Update salary (increase by 10k)
# employee[3] = 70000  # Updating salary
#
# # Step 3: Add department if missing
# if "Finance" not in employee:
#     employee.append("Finance")
#
# # Step 4: Remove old salary (60000) using remove
# employee.remove(60000)
#
# # Step 5: Update age using index lookup
# idx = employee.index(29)
# employee[idx] = 30
#
# print(employee)
# ```
#
# **Your Task**:
# - Identify **at least 3 distinct bugs**.
# - Explain what each bug does (or fails to do).
# - Rewrite the code so it correctly outputs: `["Kamran", 30, 70000, "Finance"]`.

# %% [markdown]
# ### **Debugging Task 2: Student Grade Cleanup**
# *Scenario*:
# A teacher uses a list to store student data: `[name, grade_level, average_score, "Needs Review"]`. After grading finals, they want to:
# - Keep only `[name, new_grade_level, updated_score]`
# - Dynamically update values without hardcoding indices
#
# **Buggy Code**:
# ```python
# student = ["Sana", 10, 78.5, "Needs Review"]
#
# # Update grade level from 10 → 11
# pos = student.index(10)
# student[pos] = 11
#
# # Update score to 85.0
# student[3] = 85.0  # Overwrite "Needs Review"
#
# # Remove the old score (78.5)
# student.pop(student.index(78.5))
#
# # Remove the status tag
# student.remove("Needs Review")
#
# # Append nothing—just clean up
# final_record = student[0:3]
#
# print(final_record)
# ```
#
# **Your Task**:
# - Find **all logical and runtime errors** (some may cause crashes!).
# - Explain why the current approach corrupts the data.
# - Fix the code so `final_record` is `["Sana", 11, 85.0]`.

# %% [markdown]
# ### **Debugging Task 3: Delivery Order Correction**
# *Scenario*:
# An e-commerce system represents an order as: `[customer_name, item_count, total_price, "Pending", delivery_zone]`. After verification, it should become: `[customer_name, corrected_item_count, corrected_price, delivery_zone]`.
#
# **Buggy Code**:
# ```python
# order = ["Rizwan", 3, 4500.0, "Pending", "Zone B"]
#
# # Correct item count from 3 → 4
# order[1] = 4
#
# # Update price to 6000.0
# order[2] = 6000.0
#
# # Remove status tag "Pending"
# order.pop(3)
#
# # Now remove old price (4500.0) — but it's already overwritten!
# order.remove(4500.0)
#
# # Slice to keep only relevant data
# clean_order = order[0:4]  # Should be name, items, price, zone
#
# print(clean_order)
# ```
#
# **Your Task**:
# - Identify the **critical flaw** in trying to remove `4500.0`.
# - Spot any **index or slicing issues** after popping.
# - Rewrite the logic so the final `clean_order` is `["Rizwan", 4, 6000.0, "Zone B"]`—**without ever trying to remove the old price** (since it’s already gone).
